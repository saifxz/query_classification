# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag, RegexpParser

nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")

sentence = "The quick brown fox jumps over the lazy dog."
tokens = word_tokenize(sentence)
pos_tags = pos_tag(tokens)

# Define chunk grammar (NP = Noun Phrase)
chunk_grammar = r"NP: {<DT>?<JJ>*<NN>}"
chunk_parser = RegexpParser(chunk_grammar)

chunked = chunk_parser.parse(pos_tags)
chunked.draw()  # Opens a tree visualization

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
text = "Apple was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in Cupertino."

doc = nlp(text)

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import spacy
#       3 nlp = spacy.load("en_core_web_sm")
#       4 text = "Apple was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in Cupertino."
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\spacy\__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\spacy\errors.py:3
#       1 import warnings
# ...

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

file_path = "news.txt"
with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

parser = PlaintextParser.from_string(text, Tokenizer("english"))
summarizer = LsaSummarizer()
top_sentences = summarizer(parser.document, 10)

for sentence in top_sentences:
    print(sentence)
