# %%
import nltk
from nltk import CFG
from nltk.parse.generate import generate

grammar = CFG.fromstring("""
    S -> NP VP
    NP -> Det N
    VP -> V NP
    Det -> 'the' | 'a'
    N -> 'cat' | 'dog'
    V -> 'chased' | 'ate'
""")

def generate_sentences(grammar, max_sentences=10):
    sentences = []
    for sentence in generate(grammar, depth=5):
        sentences.append(' '.join(sentence))
        if len(sentences) >= max_sentences:
            break
    return sentences

sentences = generate_sentences(grammar)
print("Generated Sentences:")
for sentence in sentences:
    print(sentence)
# Out:
# Generated Sentences:
# the cat chased the cat
# the cat chased the dog
# the cat chased a cat
# the cat chased a dog
# the cat ate the cat
# the cat ate the dog
# the cat ate a cat
# the cat ate a dog
# the dog chased the cat
# the dog chased the dog

# %%
import nltk
from nltk import pos_tag, ne_chunk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tree import Tree

# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('maxent_ne_chunker')
# nltk.download('words')

def regex_parser(text, pattern):
    return re.findall(pattern, text)

def shallow_parsing(text):
    words = word_tokenize(text)
    pos_tags = pos_tag(words)
    chunks = ne_chunk(pos_tags)
    return chunks

def get_named_entity_relations(chunks):
    named_entities = []
    for chunk in chunks:
        if isinstance(chunk, Tree):
            entity = " ".join([word for word, pos in chunk.leaves()])
            label = chunk.label()
            named_entities.append((entity, label))
    return named_entities

def get_top_sentences(file_path, top_n=10):
    with open(file_path, 'r') as file:
        text = file.read()
    sentences = sent_tokenize(text)
    return sentences[:top_n]

if __name__ == "__main__":
    text = "John Doe is a software engineer at Google. He lives in New York."
    
    pattern = r'\b[A-Z][a-z]*\b'
    matches = regex_parser(text, pattern)
    print("Regex Matches:", matches)
    
    chunks = shallow_parsing(text)
    print("Shallow Parsing Chunks:", chunks)
    
    named_entities = get_named_entity_relations(chunks)
    print("Named Entities:", named_entities)
    
    file_path = 'news_article.txt'
    top_sentences = get_top_sentences(file_path)
    print("Top 10 Sentences:", top_sentences)
# Out:
# Regex Matches: ['John', 'Doe', 'Google', 'He', 'New', 'York']
# Shallow Parsing Chunks: (S
#   (PERSON John/NNP)
#   (ORGANIZATION Doe/NNP)
#   is/VBZ
#   a/DT
#   software/NN
#   engineer/NN
#   at/IN
#   (ORGANIZATION Google/NNP)
#   ./.
#   He/PRP
#   lives/VBZ
#   in/IN
#   (GPE New/NNP York/NNP)
#   ./.)
# Named Entities: [('John', 'PERSON'), ('Doe', 'ORGANIZATION'), ('Google', 'ORGANIZATION'), ('New York', 'GPE')]
# ...

# %%
import re

def regex_parser(text, pattern):
    return re.findall(pattern, text)

text = "John Doe is a software engineer at Google. He lives in New York."
pattern = r'\b[A-Z][a-z]*\b'
matches = regex_parser(text, pattern)
print("Regex Matches:", matches)
# Out:
# Regex Matches: ['John', 'Doe', 'Google', 'He', 'New', 'York']

# %%
import nltk
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')

def shallow_parsing(text):
    words = word_tokenize(text)
    pos_tags = pos_tag(words)
    chunks = ne_chunk(pos_tags)
    return chunks

text = "John Doe is a software engineer at Google. He lives in New York."
chunks = shallow_parsing(text)
print("Shallow Parsing Chunks:", chunks)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\saiff\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\saiff\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\saiff\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\saiff\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Shallow Parsing Chunks: (S
#   (PERSON John/NNP)
#   (ORGANIZATION Doe/NNP)
#   is/VBZ
#   a/DT
#   software/NN
#   engineer/NN
#   at/IN
#   (ORGANIZATION Google/NNP)
#   ./.
#   He/PRP
#   lives/VBZ
#   in/IN
#   (GPE New/NNP York/NNP)
#   ./.)

# %%
# Out:
# Named Entities: [('John', 'PERSON'), ('Doe', 'ORGANIZATION'), ('Google', 'ORGANIZATION'), ('New York', 'GPE')]

# %%
from nltk.tokenize import sent_tokenize

def get_top_sentences(file_path, top_n=10):
    with open(file_path, 'r') as file:
        text = file.read()
    sentences = sent_tokenize(text)
    return sentences[:top_n]

file_path = 'article.txt'
top_sentences = get_top_sentences(file_path)
print("Top 10 Sentences:")
for i, sentence in enumerate(top_sentences, 1):
    print(f"{i}. {sentence}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 10
#       7     return sentences[:top_n]
#       9 file_path = 'article.txt'
# ---> 10 top_sentences = get_top_sentences(file_path)
#      11 print("Top 10 Sentences:")
#      12 for i, sentence in enumerate(top_sentences, 1):
#
# Cell In[13], line 4, in get_top_sentences(file_path, top_n)
#       3 def get_top_sentences(file_path, top_n=10):
# ----> 4     with open(file_path, 'r') as file:
#       5         text = file.read()
#       6     sentences = sent_tokenize(text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
# ...
