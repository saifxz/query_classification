# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load dataset
categories = ['alt.atheism', 'comp.graphics', 'sci.med', 'soc.religion.christian']
newsgroups = fetch_20newsgroups(subset='all', categories=categories)
X_train, X_test, y_train, y_test = train_test_split(newsgroups.data, newsgroups.target, test_size=0.2, random_state=42)

# Build pipeline
model = make_pipeline(TfidfVectorizer(), MultinomialNB())

# Train the model
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
# Out:
# Accuracy: 0.90

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Sample dataset
documents = [
    "Python is a great programming language",
    "Machine learning involves algorithms and models",
    "JavaScript is popular for web development",
    "Deep learning uses neural networks",
    "HTML and CSS are essential for front-end development"
]

# Convert to TF-IDF features
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)

# Apply KMeans
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X)

# Output cluster assignments
for i, doc in enumerate(documents):
    print(f"Document {i}: Cluster {kmeans.labels_[i]}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
#       2 from sklearn.cluster import KMeans
# ----> 3 import matplotlib.pyplot as plt
#       5 # Sample dataset
#       6 documents = [
#       7     "Python is a great programming language",
#       8     "Machine learning involves algorithms and models",
#    (...)
#      11     "HTML and CSS are essential for front-end development"
#      12 ]
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import requests
from bs4 import BeautifulSoup

# Fetch the webpage
url = "https://news.ycombinator.com/"
response = requests.get(url)

# Parse the HTML
soup = BeautifulSoup(response.text, "html.parser")

# Extract and print headlines
for item in soup.select(".titleline > a"):
    print(item.get_text())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import requests
# ----> 2 from bs4 import BeautifulSoup
#       4 # Fetch the webpage
#       5 url = "https://news.ycombinator.com/"
#
# ModuleNotFoundError: No module named 'bs4'

# %%
import tweepy

# Twitter API credentials
consumer_key = "YOUR_CONSUMER_KEY"
consumer_secret = "YOUR_CONSUMER_SECRET"
access_token = "YOUR_ACCESS_TOKEN"
access_token_secret = "YOUR_ACCESS_SECRET"

# Authenticate
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Fetch tweets
tweets = api.search_tweets(q="AI", count=5)
for tweet in tweets:
    print(tweet.text)

# %%
import requests

# Facebook API credentials
access_token = "YOUR_ACCESS_TOKEN"
page_id = "some_facebook_page_id"

# Fetch posts
url = f"https://graph.facebook.com/v12.0/{page_id}/posts?fields=id,message,likes.summary(true),comments.summary(true)&access_token={access_token}"
response = requests.get(url).json()

# Sort by engagement
posts = sorted(response["data"], key=lambda x: (x.get("likes", {}).get("summary", {}).get("total_count", 0) +
                                                x.get("comments", {}).get("summary", {}).get("total_count", 0)), 
               reverse=True)

# Display most engaged post
print(posts[0])

# %%
import matplotlib.pyplot as plt

# Sample data
influencers = ["User1", "User2", "User3", "User4"]
engagement = [1200, 3500, 2200, 800]

# Plot
plt.bar(influencers, engagement, color=['blue', 'green', 'red', 'purple'])
plt.xlabel("Influencer")
plt.ylabel("Engagement")
plt.title("Influencer Engagement Comparison")
plt.show()
